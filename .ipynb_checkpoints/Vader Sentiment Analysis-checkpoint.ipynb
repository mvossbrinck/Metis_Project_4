# %% [markdown]
# ### Import Libraries and Data Sets

# %%
import pandas as pd
import pickle
import seaborn as sns 
import matplotlib.pyplot as plt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
with open('Leslie_all.pickle','rb') as read_file:
    leslie_episodes = pickle.load(read_file)

leslie_episodes.head()
# Out:
#       Character Episode Episode_Split  \
# 0  Leslie Knope   s1e01         s1e01
# 1  Leslie Knope   s1e02         s1e02
# 2  Leslie Knope   s1e03         s1e03
# 3  Leslie Knope   s1e04         s1e04
# 4  Leslie Knope   s1e05         s1e05
#
#                                         Episode_Text
# 0  Hello. Hi. My name is Leslie Knope, and I work...
# 1  Well, one of the funner things that we do here...
# 2  The Parks Department has so many programs. Jer...
# 3  I don't believe it. Oh, my God. It's real. Hey...
# 4  In a town as old as Pawnee, there's a lot of h...

# %%
with open('Ron_all.pickle','rb') as read_file:
    ron_episodes = pickle.load(read_file)

ron_episodes.head()
# Out:
#      Character Episode Episode_Split  \
# 0  Ron Swanson   s1e01         s1e01
# 1  Ron Swanson   s1e02         s1e02
# 2  Ron Swanson   s1e03         s1e03
# 3  Ron Swanson   s1e04         s1e04
# 4  Ron Swanson   s1e05         s1e05
#
#                                         Episode_Text
# 0  Tonight is our next monthly community outreach...
# 1  Uh, sure, Paul. What can I do for you? Yeah, a...
# 2  No comment. Hey, Haverford, maybe one day you'...
# 3  Go to jail? What's going on? Put it in an emai...
# 4  The only reason anybody's going to this thing ...

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
leslie_episodes['neg'] = leslie_episodes['Episode_Text'].apply(lambda x:analyzer.polarity_scores(x)['neg'])
leslie_episodes['neu'] = leslie_episodes['Episode_Text'].apply(lambda x:analyzer.polarity_scores(x)['neu'])
leslie_episodes['pos'] = leslie_episodes['Episode_Text'].apply(lambda x:analyzer.polarity_scores(x)['pos'])
leslie_episodes['season'] = leslie_episodes['Episode'].str[:2]
leslie_episodes.head()
# Out:
#       Character Episode Episode_Split  \
# 0  Leslie Knope   s1e01         s1e01
# 1  Leslie Knope   s1e02         s1e02
# 2  Leslie Knope   s1e03         s1e03
# 3  Leslie Knope   s1e04         s1e04
# 4  Leslie Knope   s1e05         s1e05
#
#                                         Episode_Text    neg    neu    pos  \
# 0  Hello. Hi. My name is Leslie Knope, and I work...  0.035  0.776  0.189
# 1  Well, one of the funner things that we do here...  0.071  0.746  0.183
# 2  The Parks Department has so many programs. Jer...  0.074  0.746  0.180
# 3  I don't believe it. Oh, my God. It's real. Hey...  0.077  0.754  0.169
# 4  In a town as old as Pawnee, there's a lot of h...  0.048  0.744  0.207
#
#   season
# 0     s1
# 1     s1
# 2     s1
# 3     s1
# 4     s1

# %%
plt.rcParams["figure.figsize"] = (10,5)
fig, ax = plt.subplots() 
ax.set_ylim(0, .3)  
sns.lineplot(data = leslie_episodes, x = 'Episode_Split', y = 'pos', hue = 'season', ax=ax);

# %%
plt.rcParams["figure.figsize"] = (10,5)
fig, ax = plt.subplots() 
ax.set_ylim(.6, .9)  
sns.lineplot(data = leslie_episodes, x = 'Episode_Split', y = 'neu', hue = 'season', ax=ax);

# %%
plt.rcParams["figure.figsize"] = (10,5)
fig, ax = plt.subplots() 
ax.set_ylim(0, .3)  
sns.lineplot(data = leslie_episodes, x = 'Episode_Split', y = 'neg', hue = 'season', ax=ax);

# %%
leslie_episodes['Episode_Number'] = leslie_episodes.index + 1

# %%
leslie_episodes.to_csv('Leslie_Sentiment.csv')

# %%
ron_episodes['neg'] = ron_episodes['Episode_Text'].apply(lambda x:analyzer.polarity_scores(x)['neg'])
ron_episodes['neu'] = ron_episodes['Episode_Text'].apply(lambda x:analyzer.polarity_scores(x)['neu'])
ron_episodes['pos'] = ron_episodes['Episode_Text'].apply(lambda x:analyzer.polarity_scores(x)['pos'])
ron_episodes['season'] = ron_episodes['Episode'].str[:2]
#ron_episodes['Word_Count'] = ron_episodes['Episode_Text'].str.strip().str.split(" ").str.len()
ron_episodes.head()
# Out:
#      Character Episode Episode_Split  \
# 0  Ron Swanson   s1e01         s1e01
# 1  Ron Swanson   s1e02         s1e02
# 2  Ron Swanson   s1e03         s1e03
# 3  Ron Swanson   s1e04         s1e04
# 4  Ron Swanson   s1e05         s1e05
#
#                                         Episode_Text    neg    neu    pos  \
# 0  Tonight is our next monthly community outreach...  0.050  0.849  0.100
# 1  Uh, sure, Paul. What can I do for you? Yeah, a...  0.074  0.773  0.153
# 2  No comment. Hey, Haverford, maybe one day you'...  0.119  0.824  0.058
# 3  Go to jail? What's going on? Put it in an emai...  0.083  0.813  0.104
# 4  The only reason anybody's going to this thing ...  0.016  0.693  0.291
#
#   season
# 0     s1
# 1     s1
# 2     s1
# 3     s1
# 4     s1

# %%
plt.rcParams["figure.figsize"] = (10,5)
fig, ax = plt.subplots() 
ax.set_ylim(0, .3)  
sns.lineplot(data = ron_episodes, x = 'Episode_Split', y = 'pos', hue = 'season', ax=ax);

# %%
plt.rcParams["figure.figsize"] = (10,5)
fig, ax = plt.subplots() 
ax.set_ylim(.6, .9)  
sns.lineplot(data = ron_episodes, x = 'Episode_Split', y = 'neu', hue = 'season', ax=ax);

# %%
plt.rcParams["figure.figsize"] = (10,5)
fig, ax = plt.subplots() 
ax.set_ylim(0, .3)  
sns.lineplot(data = ron_episodes, x = 'Episode_Split', y = 'neg', hue = 'season', ax=ax);

# %%
ron_episodes['Episode_Number'] = ron_episodes.index + 1

# %%
ron_episodes.to_csv('Ron_Sentiment.csv')
